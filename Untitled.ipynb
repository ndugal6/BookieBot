# %%
from nba_api.stats.endpoints import commonplayerinfo
from nba_api.stats.endpoints import teamgamelog
from nba_api.stats.static import teams
from datetime import date
from nba_api.stats.static import players
from nba_api.stats.endpoints import playercareerstats
from nba_api.stats.endpoints import playergamelog
from nba_api.stats.endpoints import teamdashboardbyopponent

# %%
player_info = commonplayerinfo.CommonPlayerInfo(201935)
teamdashboardbyopponent.TeamDashboardByOpponent(team_id=1610612737, opponent_team_id=1610612738)

# %%
player_info.get_data_frames()[0].head()
# Out:
#    PERSON_ID FIRST_NAME LAST_NAME DISPLAY_FIRST_LAST DISPLAY_LAST_COMMA_FIRST  \
# 0     201935      James    Harden       James Harden            Harden, James
#
#   DISPLAY_FI_LAST            BIRTHDATE         SCHOOL COUNTRY  \
# 0       J. Harden  1989-08-26T00:00:00  Arizona State     USA
#
#     LAST_AFFILIATION  ... TEAM_CITY    PLAYERCODE  FROM_YEAR TO_YEAR  \
# 0  Arizona State/USA  ...   Houston  james_harden       2009    2019
#
#   DLEAGUE_FLAG NBA_FLAG  GAMES_PLAYED_FLAG DRAFT_YEAR DRAFT_ROUND DRAFT_NUMBER
# 0            N        Y                  Y       2009           1            3
#
# [1 rows x 30 columns]

# %%
teams.get_teams(('cav'))
# Out:
# [{'id': 1610612737,
#   'full_name': 'Atlanta Hawks',
#   'abbreviation': 'ATL',
#   'nickname': 'Hawks',
#   'city': 'Atlanta',
#   'state': 'Atlanta',
#   'year_founded': 1949},
#  {'id': 1610612738,
#   'full_name': 'Boston Celtics',
#   'abbreviation': 'BOS',
#   'nickname': 'Celtics',
#   'city': 'Boston',
#   'state': 'Massachusetts',
#   'year_founded': 1946},
#  {'id': 1610612739,
#   'full_name': 'Cleveland Cavaliers',
#   'abbreviation': 'CLE',
#   'nickname': 'Cavaliers',
#   'city': 'Cleveland',
#   'state': 'Ohio',
#   'year_founded': 1970},
#  {'id': 1610612740,
#   'full_name': 'New Orleans Pelicans',
#   'abbreviation': 'NOP',
#   'nickname': 'Pelicans',
#   'city': 'New Orleans',
#   'state': 'Louisiana',
#   'year_founded': 2002},
#  {'id': 1610612741,
#   'full_name': 'Chicago Bulls',
#   'abbreviation': 'CHI',
#   'nickname': 'Bulls',
#   'city': 'Chicago',
#   'state': 'Illinois',
#   'year_founded': 1966},
#  {'id': 1610612742,
# ...

# %%
teamgamelog.TeamGameLog('1610612737', '2019').get_data_frames()[0]
# Out:
#        Team_ID     Game_ID     GAME_DATE      MATCHUP WL  W   L  W_PCT  MIN  \
# 0   1610612737  0021900228  NOV 23, 2019  ATL vs. TOR  L  4  12  0.250  240
# 1   1610612737  0021900215  NOV 22, 2019    ATL @ DET  L  4  11  0.267  240
# 2   1610612737  0021900204  NOV 20, 2019  ATL vs. MIL  L  4  10  0.286  240
# 3   1610612737  0021900188  NOV 17, 2019    ATL @ LAL  L  4   9  0.308  240
# 4   1610612737  0021900182  NOV 16, 2019    ATL @ LAC  L  4   8  0.333  240
# 5   1610612737  0021900165  NOV 14, 2019    ATL @ PHX  L  4   7  0.364  240
# 6   1610612737  0021900150  NOV 12, 2019    ATL @ DEN  W  4   6  0.400  240
# 7   1610612737  0021900138  NOV 10, 2019    ATL @ POR  L  3   6  0.333  265
# 8   1610612737  0021900119  NOV 08, 2019  ATL vs. SAC  L  3   5  0.375  240
# 9   1610612737  0021900105  NOV 06, 2019  ATL vs. CHI  L  3   4  0.429  240
# 10  1610612737  0021900099  NOV 05, 2019  ATL vs. SAS  W  3   3  0.500  240
# ...

# %%
# teams.find_teams_by_full_name('louisiana')
# teams.find_team_name_by_id('1610612739')
teams.find_teams_by_state('louisiana')
# Out:
# [{'id': 1610612740,
#   'full_name': 'New Orleans Pelicans',
#   'abbreviation': 'NOP',
#   'nickname': 'Pelicans',
#   'city': 'New Orleans',
#   'state': 'Louisiana',
#   'year_founded': 2002}]

# %%
players.find_players_by_full_name("Stephen Curry")
# Out:
# [{'id': 201939,
#   'full_name': 'Stephen Curry',
#   'first_name': 'Stephen',
#   'last_name': 'Curry',
#   'is_active': True}]

# %%
curry_season_stats = playercareerstats.PlayerCareerStats(201935).get_data_frames()[0]
# curry_game_stats = playergamelog.PlayerGameLog(player_id=201939, season='2018').get_data_frames()[0]
curry_season_stats.head()
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     201939   2009-10        00  1610612744               GSW        22.0
# 1     201939   2010-11        00  1610612744               GSW        23.0
# 2     201939   2011-12        00  1610612744               GSW        24.0
# 3     201939   2012-13        00  1610612744               GSW        25.0
# 4     201939   2013-14        00  1610612744               GSW        26.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  80  77  2896.0  528  ...   0.885    48   308  356  472  152   19  243  252
# 1  74  74  2489.0  505  ...   0.934    52   234  286  432  109   20  226  233
# 2  26  23   732.0  145  ...   0.809    15    73   88  138   39    8   65   62
# 3  78  78  2983.0  626  ...   0.900    59   255  314  539  126   12  240  198
# 4  78  78  2846.0  652  ...   0.885    46   288  334  666  128   14  294  194
#
#     PTS
# 0  1399
# 1  1373
# 2   383
# ...

# %%
curry_season_stats.loc[curry_season_stats['SEASON_ID'] == '2019-20']
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 10     201939   2019-20        00  1610612744               GSW        31.0
#
#     GP  GS    MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# 10   4   4  112.0   27  ...     1.0     4    16   20   26    5    2   15  10
#
#     PTS
# 10   81
#
# [1 rows x 27 columns]

# %%
curry_game_stats['MIN'].max()
# Out:
# 42

# %%
t = teams.get_teams()
list(filter(lambda x: x['id'] == 1610612765, t))
# Out:
# [{'id': 1610612765,
#   'full_name': 'Detroit Pistons',
#   'abbreviation': 'DET',
#   'nickname': 'Pistons',
#   'city': 'Detroit',
#   'state': 'Michigan',
#   'year_founded': 1948}]

# %%
print(teams.find_team_by_abbreviation('NOP'))
# Out:
# {'id': 1610612740, 'full_name': 'New Orleans Pelicans', 'abbreviation': 'NOP', 'nickname': 'Pelicans', 'city': 'New Orleans', 'state': 'Louisiana', 'year_founded': 2002}

# %%
from nba_api.stats.endpoints import leaguegamefinder

# Query for games where the Celtics were playing
gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=1610612740)
# The first DataFrame of those returned is what we want.
games = gamefinder.get_data_frames()[0]
# print(games.count())
games.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION             TEAM_NAME     GAME_ID  \
# 0     22019  1610612740               NOP  New Orleans Pelicans  0021900275
# 1     22019  1610612740               NOP  New Orleans Pelicans  0021900264
# 2     22019  1610612740               NOP  New Orleans Pelicans  0021900239
# 3     22019  1610612740               NOP  New Orleans Pelicans  0021900234
# 4     22019  1610612740               NOP  New Orleans Pelicans  0021900214
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 0  2019-11-29    NOP @ OKC  L  239  104  ...   0.714     7    37   44   19
# 1  2019-11-27  NOP vs. LAL  L  239  110  ...   0.833    13    29   42   20
# 2  2019-11-24    NOP @ LAC  L  240  109  ...   0.556    12    33   45   26
# 3  2019-11-23    NOP @ UTA  L  241  120  ...   0.950     9    29   38   21
# 4  2019-11-21    NOP @ PHX  W  240  124  ...   0.636     8    36   44   28
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# ...

# %%
games.columns
# Out:
# Index(['SEASON_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID',
#        'GAME_DATE', 'MATCHUP', 'WL', 'MIN', 'PTS', 'FGM', 'FGA', 'FG_PCT',
#        'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB',
#        'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PLUS_MINUS'],
#       dtype='object')
